# %%
1. Compare and contrast NLTK and spaCy in terms of features, ease of use,
and performance.
 Ans :- 1. Features
NLTK (Natural Language Toolkit)
Very rich and wide collection of NLP tools
Includes:
Tokenization
Stemming & Lemmatization
POS tagging
Chunking
Parsing
Classical ML models (via wrappers)
Strong focus on education and research
Provides many corpora and lexical resources (e.g., WordNet)
spaCy
Focused on industrial-strength NLP
Provides:
Fast tokenization
POS tagging
Named Entity Recognition (NER)
Dependency parsing
Word vectors (pretrained embeddings)
Designed for production-ready NLP pipelines
2. Ease of Use
NLTK
More flexible but complex
Requires multiple steps for simple tasks
Good for learning NLP concepts
Example: You may need separate calls for tokenization, stopwords, etc.
spaCy
Very simple and intuitive API
Pipeline-based processing (nlp(text))
Minimal code for complex tasks
More “plug-and-play” experience

Example:

NLTK → multiple functions needed
spaCy → one pipeline call handles everything
3. Performance
NLTK
Slower because it is:
Python-based
Not optimized for large-scale processing
Better suited for:
Small datasets
Learning and experimentation
spaCy
Very fast and optimized
Written in Cython
Designed for:
Large datasets
Real-time applications
Much better memory and speed efficiency
4. Comparison Table
Feature	NLTK	spaCy
Purpose	Education & research	Production & industry
Speed	Slow	Very fast
Ease of use	Moderate to difficult	Easy & intuitive
Pretrained models	Limited	Strong (NER, embeddings)
Flexibility	Very high	Moderate
Best for	Learning NLP concepts	Real-world applications
5. Conclusion
NLTK is best for learning NLP concepts and academic work, as it provides detailed control over each step.
spaCy is best for real-world applications, where speed, efficiency, and simplicity are important.

# %% [markdown]
# 2.  What is TextBlob and how does it simplify common NLP tasks like
# sentiment analysis and translation?
#
# Ana :- TextBlob is a simple and beginner-friendly Python library built on top of NLTK and pattern that provides an easy interface for performing common Natural Language Processing (NLP) tasks.
#
# It is mainly used for:
#
# Sentiment analysis
# Part-of-speech tagging
# Noun phrase extraction
# Translation and language detection
# Tokenization
# Its main goal is to make NLP tasks simple and accessible with minimal code.
#
# How TextBlob simplifies NLP tasks
#
# 1. Sentiment Analysis
# TextBlob makes sentiment analysis very easy using built-in functionality.
# It returns:
# Polarity → range from -1 (negative) to +1 (positive)
# Subjectivity → range from 0 (objective) to 1 (subjective)

# %% [markdown]
# 3. Explain the role of Standford NLP in academic and industry NLP Projects.
#
# Ans :- Role of Stanford NLP in Academic and Industry NLP Projects
#
# The Stanford NLP toolkit (Stanford CoreNLP) is a widely used Natural Language Processing framework developed by Stanford University. It provides a collection of powerful NLP tools used for both research (academic) and real-world industry applications.
#
# 1. Role in Academic NLP Projects
#
# In academia, Stanford NLP plays a major role as a research and teaching tool.
#
# a) Standard Benchmark Toolkit
# Used in universities worldwide for NLP experiments
# Provides baseline models for comparison in research papers
# b) Rich NLP Components for Study
#
# Stanford CoreNLP includes:
#
# Tokenization
# Sentence splitting
# Part-of-speech (POS) tagging
# Named Entity Recognition (NER)
# Dependency parsing
# Coreference resolution
# Sentiment analysis
#
# These help students understand linguistic structure and NLP fundamentals deeply.
#
# c) Supports Research and Experimentation
# Allows researchers to test new NLP algorithms
# Helps evaluate improvements over traditional methods
# Frequently used in published NLP research papers
# d) Multilingual Support
# Supports multiple languages (English is most advanced)
# Useful for comparative linguistic studies
# 2. Role in Industry NLP Projects
#
# In industry, Stanford NLP is used in real-world applications, especially where accuracy and linguistic depth are important.
#
# a) Information Extraction Systems
# Extracts structured data from unstructured text
# Used in:
# Finance reports
# Legal documents
# News analysis
# b) Sentiment Analysis
# Helps companies analyze customer feedback
# Used in:
# Product reviews
# Social media monitoring
# Brand reputation analysis
# c) Chatbots and Virtual Assistants
# Helps understand user queries using:
# POS tagging
# dependency parsing
# Improves intent detection and response quality
# d) Named Entity Recognition (NER) Applications
#
# Used to identify:
#
# Names of people
# Organizations
# Locations
# Dates and monetary values
#
# Example use cases:
#
# Banking (fraud detection)
# Healthcare (extracting patient info)
# E-commerce (product tagging)
# e) Document Analysis
# Legal document processing
# Contract analysis
# News classification

# %% [markdown]
# 4. Describe the architecture and functioning of a Recurrent Natural Network
# (RNN).
#
# Ans :- 1. Architecture of RNN
#
# An RNN has a repeating structure (loop) where the output of one step is passed as input to the next.
#
# Main Components:
# Input layer: Takes sequential input (e.g., words in a sentence)
# Hidden layer (recurrent layer): Stores information from previous time steps
# Output layer: Produces prediction at each step or final output
# Hidden state (memory): Carries context from earlier inputs
# Key Idea:
#
# Each hidden state depends on:
#
# Current input
# Previous hidden state
#
# Mathematically:
#
# h
# t
# 	​
#
# =f(W
# x
# 	​
#
# x
# t
# 	​
#
# +W
# h
# 	​
#
# h
# t−1
# 	​
#
# )
# y
# t
# 	​
#
# =g(W
# y
# 	​
#
# h
# t
# 	​
#
# )
#
# Where:
#
# h
# t
# 	​
#
#  = hidden state at time t
# x
# t
# 	​
#
#  = input at time t
# h
# t−1
# 	​
#
#  = previous hidden state
# 2. Functioning of RNN
#
# RNN processes data step-by-step in sequence:
#
# Step-by-step process:
# Takes first input (e.g., first word in a sentence)
# Computes hidden state
# Passes hidden state to next step
# Repeats for all inputs in sequence
# Produces output (final or at each step)
# 3. Example
#
# Sentence: “I love NLP”
#
# Step 1: “I” → hidden state h₁
# Step 2: “love” + h₁ → h₂
# Step 3: “NLP” + h₂ → h₃ → output
#
# This allows the network to understand context of previous words.
#
# 4. Working Diagram (Conceptual)
# x1 → h1 → h2 → h3 → y
#      ↑    ↑    ↑
#     x2   x3   x4

# %% [markdown]
# 5. What is the key difference between LSTM and GRU networks in NLP
# applications?
#
#
# Ans :- Key Difference Between LSTM and GRU
# 1. Architecture
# LSTM: Has three gates
# Input gate
# Forget gate
# Output gate
# Also maintains a cell state (memory) in addition to hidden state.
# GRU: Has two gates
# Reset gate
# Update gate
# It combines cell state and hidden state into one.
# 2. Complexity
# LSTM: More complex (more parameters, slower training)
# GRU: Simpler and more efficient (fewer parameters)
# 3. Performance
# LSTM: Performs slightly better on very long sequences
# GRU: Performs similarly in most cases, sometimes better for smaller datasets
# 4. Memory Handling
# LSTM: Separates long-term memory (cell state) and short-term memory (hidden state)
# GRU: Uses a single state to manage memory
# 5. Speed
# LSTM: Slower due to complex structure
# GRU: Faster and computationally efficient

# %%
""" Write a Python program using TextBlob to perform sentiment analysis on
the following paragraph of text:
“I had a great experience using the new mobile banking app. The interface is intuitive,
and customer support was quick to resolve my issue. However, the app did crash once
during a transaction, which was frustrating"
Your program should print out the polarity and subjectivity scores."""

from textblob import TextBlob

# Input text
text = """
I had a great experience using the new mobile banking app.
The interface is intuitive, and customer support was quick to resolve my issue.
However, the app did crash once during a transaction, which was frustrating
"""

# Create TextBlob object
blob = TextBlob(text)

# Get sentiment
sentiment = blob.sentiment

# Print results
print("Polarity:", sentiment.polarity)
print("Subjectivity:", sentiment.subjectivity)
# Out:
# Polarity: 0.21742424242424244
# Subjectivity: 0.6511363636363636

# %%
""" Given the sample paragraph below, perform string tokenization and
frequency distribution using Python and NLTK:
“Natural Language Processing (NLP) is a fascinating field that combines linguistics,
computer science, and artificial intelligence. It enables machines to understand,
interpret, and generate human language. Applications of NLP include chatbots,
sentiment analysis, and machine translation. As technology advances, the role of NLP
in modern solutions is becoming increasingly critical.”"""

import nltk
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist

# Download required resources (run once)
nltk.download('punkt')

# Input paragraph
text = """Natural Language Processing (NLP) is a fascinating field that combines linguistics,
computer science, and artificial intelligence. It enables machines to understand,
interpret, and generate human language. Applications of NLP include chatbots,
sentiment analysis, and machine translation. As technology advances, the role of NLP
in modern solutions is becoming increasingly critical."""

# Step 1: Tokenization
tokens = tokenization (text)

print("Tokens:")
print(tokens)

# Step 2: Frequency Distribution
fdist = FreqDist(tokens)

print("\nWord Frequency Distribution:")
for word, freq in fdist.most_common():
    print(word, ":", freq)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1074/1741041569.py in <cell line: 0>()
#      22
#      23 # Step 1: Tokenization
# ---> 24 tokens = tokenization (text)
#      25
#      26 print("Tokens:")
#
# NameError: name 'tokenization' is not defined

# %%
"""Implement a basic LSTM model in Keras for a text classification task using
the following dummy dataset. Your model should classify sentences as either positive
(1) or negative (0).
# Dataset
texts = [
“I love this project”, #Positive
“This is an amazing experience”, #Positive
“I hate waiting in line”, #Negative
“This is the worst service”, #Negative
“Absolutely fantastic!” #Positive
]
labels = [1, 1, 0, 0, 1]
Preprocess the text, tokenize it, pad sequences, and build an LSTM model to train on
this data. You may use Keras with TensorFlow backend."""

import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

# -------------------------
# Dataset
# -------------------------
texts = [
    "I love this project",
    "This is an amazing experience",
    "I hate waiting in line",
    "This is the worst service",
    "Absolutely fantastic!"
]

labels = [1, 1, 0, 0, 1]

# -------------------------
# 1. Tokenization
# -------------------------
tokenizer = Tokenizer()
tokenizer.fit_on_texts(texts)

sequences = tokenizer.texts_to_sequences(texts)

# -------------------------
# 2. Padding sequences
# -------------------------
max_len = max(len(seq) for seq in sequences)
X = pad_sequences(sequences, maxlen=max_len, padding='post')

y = np.array(labels)

# Vocabulary size
vocab_size = len(tokenizer.word_index) + 1

# -------------------------
# 3. Build LSTM Model
# -------------------------
model = Sequential()

model.add(Embedding(input_dim=vocab_size, output_dim=16, input_length=max_len))
model.add(LSTM(32))
model.add(Dense(1, activation='sigmoid'))

# -------------------------
# 4. Compile Model
# -------------------------
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# -------------------------
# 5. Train Model
# -------------------------
model.fit(X, y, epochs=20, verbose=1)

# -------------------------
# 6. Test Prediction
# -------------------------
test_text = ["I really love this amazing service"]
test_seq = tokenizer.texts_to_sequences(test_text)
test_pad = pad_sequences(test_seq, maxlen=max_len, padding='post')

prediction = model.predict(test_pad)

print("\nPrediction score:", prediction)
print("Sentiment:", "Positive" if prediction > 0.5 else "Negative")
# Out:
# Epoch 1/20
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - accuracy: 0.4000 - loss: 0.6936
# Epoch 2/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6000 - loss: 0.6921
# Epoch 3/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.6000 - loss: 0.6907
# Epoch 4/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.6000 - loss: 0.6893
# Epoch 5/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.6000 - loss: 0.6879
# Epoch 6/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6000 - loss: 0.6865
# Epoch 7/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6000 - loss: 0.6850
# Epoch 8/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6000 - loss: 0.6835
# Epoch 9/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6000 - loss: 0.6819
# Epoch 10/20
# ...

# %%
"""Using spaCy, build a simple NLP pipeline that includes tokenization,
lemmatization, and entity recognition. Use the following paragraph as your dataset:
“Homi Jehangir Bhaba was an Indian nuclear physicist who played a key role in the
development of India’s atomic energy program. He was the founding director of the Tata
Institute of Fundamental Research (TIFR) and was instrumental in establishing the
Atomic Energy Commission of India.”
Write a Python program that processes this text using spaCy, then prints tokens, their
lemmas, and any named entities found."""

import spacy

# Load spaCy English model
nlp = spacy.load("en_core_web_sm")

# Input text
text = """
Homi Jehangir Bhaba was an Indian nuclear physicist who played a key role in the development of India’s atomic energy program.
He was the founding director of the Tata Institute of Fundamental Research (TIFR) and was instrumental in establishing the Atomic Energy Commission of India.
"""

# Process text through spaCy pipeline
doc = nlp(text)

# -------------------------
# 1. Tokenization & Lemmatization
# -------------------------
print("TOKENS AND LEMMAS:\n")
for token in doc:
    if not token.is_punct and not token.is_space:
        print(f"{token.text} -> {token.lemma_}")

# -------------------------
# 2. Named Entity Recognition
# -------------------------
print("\nNAMED ENTITIES:\n")
for ent in doc.ents:
    print(f"{ent.text} -> {ent.label_}")
# Out:
# TOKENS AND LEMMAS:
#
# Homi -> Homi
# Jehangir -> Jehangir
# Bhaba -> Bhaba
# was -> be
# an -> an
# Indian -> indian
# nuclear -> nuclear
# physicist -> physicist
# who -> who
# played -> play
# a -> a
# key -> key
# role -> role
# in -> in
# the -> the
# development -> development
# of -> of
# India -> India
# ’s -> ’s
# atomic -> atomic
# energy -> energy
# program -> program
# He -> he
# was -> be
# the -> the
# founding -> found
# director -> director
# of -> of
# the -> the
# Tata -> Tata
# Institute -> Institute
# of -> of
# Fundamental -> Fundamental
# Research -> Research
# TIFR -> TIFR
# and -> and
# was -> be
# instrumental -> instrumental
# in -> in
# establishing -> establish
# the -> the
# Atomic -> Atomic
# Energy -> Energy
# Commission -> Commission
# of -> of
# India -> India
#
# NAMED ENTITIES:
#
# Indian -> NORP
# India -> GPE
# the Tata Institute of Fundamental Research -> ORG
# the Atomic Energy Commission of India -> ORG

# %%
"""You are working on a chatbot for a mental health platform. Explain how
you would leverage LSTM or GRU networks along with libraries like spaCy or Stanford
NLP to understand and respond to user input effectively. Detail your architecture, data
preprocessing pipeline, and any ethical considerations."""

import spacy
import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

# Load spaCy model
nlp = spacy.load("en_core_web_sm")

# -----------------------------
# 1. Sample Dataset (Emotion Labels)
# -----------------------------
texts = [
    "I feel very sad and hopeless",
    "I am extremely anxious and stressed",
    "I am happy and feeling good",
    "Life is depressing and I feel alone",
    "I am excited and full of energy",
    "I cannot sleep and feel worried"
]

labels = [0, 0, 1, 0, 1, 0]
# 0 = Negative (sad/anxious), 1 = Positive

# -----------------------------
# 2. Preprocessing using spaCy
# -----------------------------
def preprocess(text):
    doc = nlp(text.lower())
    tokens = [token.lemma_ for token in doc if token.is_alpha]
    return " ".join(tokens)

processed_texts = [preprocess(t) for t in texts]

# -----------------------------
# 3. Tokenization
# -----------------------------
tokenizer = Tokenizer()
tokenizer.fit_on_texts(processed_texts)

sequences = tokenizer.texts_to_sequences(processed_texts)

max_len = max(len(seq) for seq in sequences)
X = pad_sequences(sequences, maxlen=max_len, padding='post')

y = np.array(labels)

vocab_size = len(tokenizer.word_index) + 1

# -----------------------------
# 4. Build LSTM Model
# -----------------------------
model = Sequential()
model.add(Embedding(vocab_size, 16, input_length=max_len))
model.add(LSTM(32))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# -----------------------------
# 5. Train Model
# -----------------------------
model.fit(X, y, epochs=30, verbose=0)

# -----------------------------
# 6. Response Function
# -----------------------------
def chatbot_response(text):
    clean = preprocess(text)
    seq = tokenizer.texts_to_sequences([clean])
    pad = pad_sequences(seq, maxlen=max_len, padding='post')

    pred = model.predict(pad)[0][0]

    if pred < 0.5:
        return "I'm really sorry you're feeling this way. Please take care of yourself and consider talking to someone you trust."
    else:
        return "I'm glad you're feeling better! Keep focusing on positive things."

# -----------------------------
# 7. Test Chatbot
# -----------------------------
test_input = "I feel very stressed and cannot sleep"
print("User:", test_input)
print("Bot:", chatbot_response(test_input))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# User: I feel very stressed and cannot sleep
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step
# Bot: I'm really sorry you're feeling this way. Please take care of yourself and consider talking to someone you trust.
